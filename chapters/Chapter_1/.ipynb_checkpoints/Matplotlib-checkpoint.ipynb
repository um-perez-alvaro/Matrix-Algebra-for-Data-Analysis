# %% [markdown]
# # The Matplotlib library

# %% [markdown]
# [Matplotlib](https://matplotlib.org/) is a powerful plotting library for Python, used to create static, animated, and interactive visualizations.
# It is widely used in Data Science and Machine Learning for its versatility and ease of use.
# With Matplotlib, we can generate plots, histograms, bar charts, scatter plots, and more.
# It helps in visualizing data to understand trends, patterns, and insights, making data analysis more intuitive and effective.

# %% [markdown]
# ## **Table of contents:**
#
# * [Importing the Matplotlib library](#import)
# * [Basic plotting with Matplotlib](#basic_plotting)
# * [Different types of plots](#types_of_plots)
#     * [Line plots](#line_plots)
#     * [Scatter plots](#scatter_plots)
#     * [Bar charts](#bar_plots)
#     * [Histograms](#histogram_plots)
#     * [Pie charts](#pie_plots)
# * [Subplots](#subplots)

# %% [markdown]
# # 1. IMPORTING THE MATPLOTLIB LIBRARY <a class="anchor" id="import"></a>

# %% [markdown]
# To use Matplotlib in your Python code, you need to import it first.
# The commonly used alias for Matplotlib's `pyplot` module is `plt`.
# This alias makes it easier to reference the `pyplot` functions and is a widely adopted convention in the data science community.
# We will also import `numpy`.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# By importing Matplotlib this way, you can use `plt` to call various plotting functions.

# %% [markdown]
# # 2. BASIC PLOTTING WITH MATPLOTLIB <a class="anchor" id="basic_plotting"></a>

# %% [markdown]
# In this section, we will start with some basic plotting using Matplotlib.
# First, we will create some toy data using NumPy.
# Then, we will make a line plot to visualize this data. We will also customize the plot by adding titles, labels, and a legend.

# %% [markdown]
# First, let's generate some toy data.
# We'll create an array of values from 0 to 10 and compute their sine values.

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %% [markdown]
# Now, let's create a simple line plot using Matplotlib.
# The `plt.plot` function creates a line plot by default.

# %%
plt.plot(x, y)

# %% [markdown]
# We can customize our plot by adding a title, legend, axis labels, a label to our line, and grid lines.

# %%
plt.plot(x, y, label='Sine Wave')
# add legend
plt.legend()
# add a title
plt.title('Simple Plot')
# add axes labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# add grid lines
plt.grid(True)

# %% [markdown]
# # 3. DIFFERENT TYPES OF PLOTS  <a class="anchor" id="types_of_plots"></a>

# %% [markdown]
# In this section, we will explore various types of plots that Matplotlib can create.
# We will start by generating some toy data using NumPy, and then we will create line plots, scatter plots, bar charts, histograms, and pie charts.

# %% [markdown]
# ## 3.1. LINE PLOTS <a class="anchor" id="line_plots"></a>

# %% [markdown]
# First, we will create a simple line plot. Line plots are useful for visualizing trends over a continuous range.

# %%
# Generate some data
x = np.linspace(-1,1,100)
y = np.random.randn(100)
y = np.cumsum(y)
plt.plot(x,y)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# ## 3.2. SCATTER PLOTS <a class="anchor" id="scatter_plots"></a>

# %% [markdown]
# Next, we will create a scatter plot. Scatter plots are useful for visualizing the relationship between two variables.

# %%
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# ## 3.3. BAR CHARTS <a class="anchor" id="bar_plots"></a>

# %% [markdown]
# Bar charts are useful for comparing different categories or groups. Here, we'll create a bar chart to show some categorical data.

# %%
# Generate some categorical data
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 2]

# Create a bar chart
plt.bar(categories, values)
plt.title('Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %% [markdown]
# ## 3.4. HISTOGRAMS <a class="anchor" id="histogram_plots"></a>

# %% [markdown]
# Histograms are useful for visualizing the distribution of a dataset. Here, we’ll create a histogram to show the distribution of random data.

# %%
# Generate some random data
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30)
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 3.5. PIE CHARTS <a class="anchor" id="pie_plots"></a>

# %% [markdown]
# Pie charts are useful for showing proportions of a whole. Here, we’ll create a pie chart to visualize some categorical data.

# %%
# Generate some data
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart')
# Out:
# Text(0.5, 1.0, 'Pie Chart')

# %% [markdown]
# ## 4. SUBPLOTS <a class="anchor" id="subplots"></a>

# %% [markdown]
# In this section, we will explore some advanced plotting techniques using Matplotlib.
# We will learn how to create subplots, customize them, and use shared axes and grid specifications.

# %% [markdown]
# Subplots allow you to create multiple plots in a single figure. This is useful for comparing different datasets or visualizing different aspects of the same data.

# %%
# Generate some data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create subplots
fig, ax = plt.subplots()
ax.plot(x, y1)
ax.plot(x, y2)
ax.set_title('Subplot Example')
# Out:
# Text(0.5, 1.0, 'Subplot Example')

# %% [markdown]
# We can customize our subplots by adding titles, labels, and legends, and by adjusting their layout.

# %%
fig, ax = plt.subplots()
ax.plot(x, y1, label='Sine')
ax.plot(x, y2, label='Cosine')
ax.set_title('Customized Subplot')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.legend()
ax.grid(True)

# %% [markdown]
# Using shared axes and specifying the grid layout can help in comparing plots by aligning them on the same scale.
#
# In this example, we create a 2x2 grid of plots with shared x and y axes.
# Each subplot shows a different transformation of the sine wave, making it easy to compare them.

# %%
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Sine Wave')
axs[0, 1].plot(x, -y1)
axs[0, 1].set_title('Negative Sine Wave')
axs[1, 0].plot(-x, y1)
axs[1, 0].set_title('Inverted Sine Wave')
axs[1, 1].plot(-x, -y1)
axs[1, 1].set_title('Inverted Negative Sine Wave')
plt.tight_layout()
